# %%
#Datos proyecto TEA

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
datos=pd.read_csv("datos.csv")

# %%
datos
# Out:
#      n                  nombre    marca     tamaño  precio
# 0    1           LEÑADOR 16 EW   Rainbow      18 L     NaN
# 1    2          TORBAN 30.4 SL   Rainbow      18 L     NaN
# 2    3         ABAMECTAN1.8 EC   Rainbow     0.1 L     NaN
# 3    4           KILLIGAN 24SC   Rainbow    0.25 L     NaN
# 4    5           REMATES 55 EC   Rainbow    O.25 L     NaN
# 5    6        SEMNTHAL 30.4 SL   Rainbow      18 L     NaN
# 6    7           SPANVIC 12 SC   Rainbow       1 L     NaN
# 7    8          CONFRONT 15 OD   Rainbow    O.25 L     NaN
# 8    9     RESPALDO PLUS 30 OD   Rainbow       1 L     NaN
# 9   10         CAMUFLAJE 35 DS   Rainbow  0.125 KG     NaN
# 10  11        MACRON XTRA 5 SG   Rainbow  0.125 KG     NaN
# 11  12      SUPERMECTIN 1.8 EC   Rainbow     0.1 L     NaN
# 12  13     SHAOLIN FORTE 25 CS   Rainbow     0.1 L     NaN
# 13  14          ATTITUDE 20 SG   Rainbow    O.2 KG     NaN
# 14  15       DELTA-TRI 21.2 EC   Rainbow    0.25 L     NaN
# 15  16      DELATA-TRI 21.2 EC   Rainbow       1 L     NaN
# 16  17          FIPROMAX 80 WG   Rainbow   O.O1 KG     NaN
# 17  18     SHAOLIN FORTE 25 CS   Rainbow   0.250 L     NaN
# 18  19           VORAZ 35.6 SL   Rainbow     3.5 L     NaN
# 19  20           VORAZ 35.6 SL   Rainbow       1 L     NaN
# 20  21     REVOLVER PLUS 54 SL   Rainbow      18 L     NaN
# 21  22        REVOLVER 35.6 SL   Rainbow      1  L     NaN
# 22  23             LAVAX 20 SL   Rainbow       5 L     NaN
# 23  24        DUIMAXINE 72 SL    Rainbow       1 L     NaN
# 24  25         DIMAXINE 60 SL    Rainbow       1 L     NaN
# 25  26         TERRAQUAT 20 SL   Rainbow       5 L     NaN
# 26  27           DACOMAX 72 SC   Rainbow       1 L     NaN
# 27  28           CURAXIL 50 WP   Rainbow    0.2 KG     NaN
# 28  29           CURAXIL 50 WP   Rainbow     O.2KG     NaN
# 29  30         COMPA DUO 84 WG   Rainbow    0.1 KG     NaN
# 30  31       ASTUTO PLUS 70 WG   Rainbow      1 KG     NaN
# 31  32           ARRAIGO 57 EC   Rainbow      18 L     NaN
# 32  33      ACROMORPH MZ 69 WP   Rainbow   0.75 KG     NaN
# 33  34           POPRICE 32 EC   Rainbow       1 L     NaN
# 34  35           FUSARIM 50 SC   Rainbow       1 L     NaN
# 35  36        FOMEX PLUS 18 EC   Rainbow     0.5 L     NaN
# 36  37            ETILEX 20 SC   Rainbow       1 L     NaN
# 37  38           CLOMIT 20 SC    Rainbow      1 KG     NaN
# 38  39       REDOBLANTE 18 EC    Rainbow     O.5 L     NaN
# 39  40        DIMASTER 46.5 SL   Rainbow       1 L     NaN
# 40  41          UPIXIAL 10 EC    Rainbow     0.1 L     NaN
# 41  42                SURFACID    Quimia       1 L     NaN
# 42  43           HEXACTO 75 WP   Foragro     10 KG     NaN
# 43  44  NUTRI AKTIV ALGAE PLUS   Spachem       1 L     NaN
# 44  45              CRECIPLANT    Quimia       1 L     NaN
# 45  46                    H-85  Cosmocel     10 KG     NaN
# 46  47          MAXIGROW EXCEL  Cosmocel      1 KG     NaN
# 47  48            BUNKER 35 FS   Rainbow       1 L     NaN
# 48  49             MANTA 60 FS       NaN   2.50 Ml     NaN
# 49  50          TRATAVIN 35 FS       NaN    454 Gr     NaN
# 50  51    TRATAVIN SUPER 54 FS       NaN  5.125 Gr     NaN

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.plot(datos.n, datos.nombre)
plt.show()
plt.rcParams['figure.figsize']=[20,20]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.scatter(datos.n, datos.nombre)
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.bar(datos.tamaño, datos.n)
plt.show()
