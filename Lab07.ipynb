# %%
#Datos proyecto TEA

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
datos=pd.read_csv("datos.csv")

# %%
datos
# Out:
#      n                  nombre    marca    tamañ0  precio
# 0    1           LEÑADOR 16 EW   Rainbow   18.000       6
# 1    2          TORBAN 30.4 SL   Rainbow   18.000       5
# 2    3         ABAMECTAN1.8 EC   Rainbow   18.000       4
# 3    4           KILLIGAN 24SC   Rainbow    2.500       1
# 4    5           REMATES 55 EC   Rainbow    0.250       1
# 5    6        SEMNTHAL 30.4 SL   Rainbow   18.000       5
# 6    7           SPANVIC 12 SC   Rainbow    1.000       2
# 7    8          CONFRONT 15 OD   Rainbow    0.250       6
# 8    9     RESPALDO PLUS 30 OD   Rainbow    1.000       5
# 9   10         CAMUFLAJE 35 DS   Rainbow   18.000       8
# 10  11        MACRON XTRA 5 SG   Rainbow   18.000       7
# 11  12      SUPERMECTIN 1.8 EC   Rainbow   18.000       5
# 12  13     SHAOLIN FORTE 25 CS   Rainbow   18.000       5
# 13  14          ATTITUDE 20 SG   Rainbow    0.200       8
# 14  15       DELTA-TRI 21.2 EC   Rainbow    2.500       5
# ...

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.plot(datos.n, datos.nombre)
plt.show()
plt.rcParams['figure.figsize']=[20,20]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.scatter(datos.n, datos.nombre)
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.bar(datos.tamaño, datos.n)
plt.show()
plt.rcParams['figure.figsize']=[20,30]

# %%
import pandas as pd
from matplotlib import pyplot as plt
datos=pd.read_csv("datos.csv")
datos
# Out:
#      n                  nombre    marca    tamaño  precio  grupo
# 0    1           LEÑADOR 16 EW   Rainbow   18.000       6      1
# 1    2          TORBAN 30.4 SL   Rainbow   18.000       8      1
# 2    3         ABAMECTAN1.8 EC   Rainbow   18.000       2      1
# 3    4           KILLIGAN 24SC   Rainbow    2.500       5      1
# 4    5           REMATES 55 EC   Rainbow    0.250       1      1
# 5    6        SEMNTHAL 30.4 SL   Rainbow   18.000       1      1
# 6    7           SPANVIC 12 SC   Rainbow    1.000       5      1
# 7    8          CONFRONT 15 OD   Rainbow    0.250       3      1
# 8    9     RESPALDO PLUS 30 OD   Rainbow    1.000       5      1
# 9   10         CAMUFLAJE 35 DS   Rainbow   18.000       0      1
# 10  11        MACRON XTRA 5 SG   Rainbow   18.000       7      1
# 11  12      SUPERMECTIN 1.8 EC   Rainbow   18.000       8      1
# 12  13     SHAOLIN FORTE 25 CS   Rainbow   18.000       3      1
# ...

# %%
grupo1=datos[datos.grupo==1]
grupo1
# Out:
#      n               nombre   marca   tamaño  precio  grupo
# 0    1        LEÑADOR 16 EW  Rainbow   18.00       6      1
# 1    2       TORBAN 30.4 SL  Rainbow   18.00       8      1
# 2    3      ABAMECTAN1.8 EC  Rainbow   18.00       2      1
# 3    4        KILLIGAN 24SC  Rainbow    2.50       5      1
# 4    5        REMATES 55 EC  Rainbow    0.25       1      1
# 5    6     SEMNTHAL 30.4 SL  Rainbow   18.00       1      1
# 6    7        SPANVIC 12 SC  Rainbow    1.00       5      1
# 7    8       CONFRONT 15 OD  Rainbow    0.25       3      1
# 8    9  RESPALDO PLUS 30 OD  Rainbow    1.00       5      1
# 9   10      CAMUFLAJE 35 DS  Rainbow   18.00       0      1
# 10  11     MACRON XTRA 5 SG  Rainbow   18.00       7      1
# 11  12   SUPERMECTIN 1.8 EC  Rainbow   18.00       8      1
# 12  13  SHAOLIN FORTE 25 CS  Rainbow   18.00       3      1
# 13  14       ATTITUDE 20 SG  Rainbow    0.20       7      1
# 14  15    DELTA-TRI 21.2 EC  Rainbow    2.50       2      1
# ...

# %%
grupo2=datos[datos.grupo==2]
grupo2
# Out:
#      n                  nombre    marca    tamaño  precio  grupo
# 25  26         TERRAQUAT 20 SL   Rainbow    5.000       2      2
# 26  27           DACOMAX 72 SC   Rainbow    1.000       3      2
# 27  28           CURAXIL 50 WP   Rainbow    0.200       0      2
# 28  29           CURAXIL 50 WP   Rainbow    0.200       7      2
# 29  30         COMPA DUO 84 WG   Rainbow   18.000       2      2
# 30  31       ASTUTO PLUS 70 WG   Rainbow    1.000       2      2
# 31  32           ARRAIGO 57 EC   Rainbow   18.000       1      2
# 32  33      ACROMORPH MZ 69 WP   Rainbow    0.750       3      2
# 33  34           POPRICE 32 EC   Rainbow    1.000       7      2
# 34  35           FUSARIM 50 SC   Rainbow    1.000       0      2
# 35  36        FOMEX PLUS 18 EC   Rainbow    7.000       3      2
# 36  37            ETILEX 20 SC   Rainbow    1.000       3      2
# 37  38           CLOMIT 20 SC    Rainbow    1.000       7      2
# ...

# %%
plt.style.use('dark_background')


plt.plot(uno.n, uno.nombre)
plt.plot(dos.n, dos.nombre)
plt.legend(["Grupo 1", "Grupo 2"])
plt.xlabel("Numero")
plt.ylabel("Nombre")
plt.show()
