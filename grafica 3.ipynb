# %%
import pandas as pd
from matplotlib import pyplot as plt
datos=pd.read_csv("datos.csv")
datos
fig, ax = plt.subplots()
ax.bar(datos.precio, datos.nombre)
plt.show()
plt.rcParams['figure.figsize']=[40,40]
