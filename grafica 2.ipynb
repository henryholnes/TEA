# %%
import pandas as pd
from matplotlib import pyplot as plt
datos=pd.read_csv("datos.csv")
datos
fig, ax = plt.subplots()
ax.scatter(datos.n, datos.nombre)
plt.rcParams['figure.figsize']=[30,30]
plt.show()
